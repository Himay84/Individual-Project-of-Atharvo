# %% [markdown]
# # CASE STUDY OF STUDENT EXAM SCORE :-

# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # For import dataset:-

# %%
data=pd.read_csv("students exam score.csv")
data
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %% [markdown]
# # To check number of rows and columns:-

# %%
data.shape
# Out:
# (30641, 15)

# %% [markdown]
# # To check size of a dataset:-

# %%
data.size
# Out:
# 459615

# %% [markdown]
# # To show first 5 row

# %%
data.head()
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female         NaN   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard      NaN
# 2           2  female     group B     master's degree      standard     none
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
# ...

# %% [markdown]
# # To show first any number of row:-

# %%
data.head(20)
# Out:
#     Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0            0  female         NaN   bachelor's degree      standard
# 1            1  female     group C        some college      standard
# 2            2  female     group B     master's degree      standard
# 3            3    male     group A  associate's degree  free/reduced
# 4            4    male     group C        some college      standard
# 5            5  female     group B  associate's degree      standard
# 6            6  female     group B        some college      standard
# 7            7    male     group B        some college  free/reduced
# 8            8    male     group D         high school  free/reduced
# 9            9  female     group B         high school  free/reduced
# 10          10    male     group C  associate's degree      standard
# 11          11    male     group D  associate's degree      standard
# 12          12  female     group B         high school      standard
# ...

# %%
print(data.head())
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female         NaN   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard      NaN
# 2           2  female     group B     master's degree      standard     none
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
# ...

# %% [markdown]
# # To show columms

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Gender', 'EthnicGroup', 'ParentEduc', 'LunchType',
#        'TestPrep', 'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild',
#        'NrSiblings', 'TransportMeans', 'WklyStudyHours', 'MathScore',
#        'ReadingScore', 'WritingScore'],
#       dtype='object')

# %% [markdown]
# # check datatype

# %%
data.dtypes
# Out:
# Unnamed: 0               int64
# Gender                  object
# EthnicGroup             object
# ParentEduc              object
# LunchType               object
# TestPrep                object
# ParentMaritalStatus     object
# PracticeSport           object
# IsFirstChild            object
# NrSiblings             float64
# TransportMeans          object
# WklyStudyHours          object
# MathScore                int64
# ReadingScore             int64
# WritingScore             int64
# dtype: object

# %% [markdown]
# # To describe the data:-

# %%
data.describe()
# Out:
#          Unnamed: 0    NrSiblings     MathScore  ReadingScore  WritingScore
# count  30641.000000  29069.000000  30641.000000  30641.000000  30641.000000
# mean     499.556607      2.145894     66.558402     69.377533     68.418622
# std      288.747894      1.458242     15.361616     14.758952     15.443525
# min        0.000000      0.000000      0.000000     10.000000      4.000000
# 25%      249.000000      1.000000     56.000000     59.000000     58.000000
# 50%      500.000000      2.000000     67.000000     70.000000     69.000000
# 75%      750.000000      3.000000     78.000000     80.000000     79.000000
# max      999.000000      7.000000    100.000000    100.000000    100.000000

# %% [markdown]
# # To check how many null values in the data set:-

# %%
data.isnull()
# Out:
#        Unnamed: 0  Gender  EthnicGroup  ParentEduc  LunchType  TestPrep  \
# 0           False   False         True       False      False     False
# 1           False   False        False       False      False      True
# 2           False   False        False       False      False     False
# 3           False   False        False       False      False     False
# 4           False   False        False       False      False     False
# ...           ...     ...          ...         ...        ...       ...
# 30636       False   False        False       False      False     False
# 30637       False   False        False       False      False     False
# 30638       False   False         True       False      False     False
# 30639       False   False        False       False      False     False
# 30640       False   False        False       False      False     False
#
#        ParentMaritalStatus  PracticeSport  IsFirstChild  NrSiblings  \
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %% [markdown]
# # To delete any column from the dataset:-

# %%
df=pd.DataFrame(data)
del df['Unnamed: 0']
df
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType   TestPrep  \
# 0      female         NaN   bachelor's degree      standard       none
# 1      female     group C        some college      standard        NaN
# 2      female     group B     master's degree      standard       none
# 3        male     group A  associate's degree  free/reduced       none
# 4        male     group C        some college      standard       none
# ...       ...         ...                 ...           ...        ...
# 30636  female     group D         high school      standard       none
# 30637    male     group E         high school      standard       none
# 30638  female         NaN         high school  free/reduced  completed
# 30639  female     group D  associate's degree      standard  completed
# 30640    male     group B        some college      standard       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %% [markdown]
# # To change any value in the dataset:-

# %%
data["WklyStudyHours"]=data["WklyStudyHours"].str.replace("05-Oct","5-10")
data
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
data["PracticeSport"]=data["PracticeSport"].str.replace("regularly","everyday")
data
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %% [markdown]
# # GENDER DISTRIBUTION

# %%
data['Gender'].value_counts()
# Out:
# Gender
# female    15424
# male      15217
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,5))
AX=sns.countplot(data=data,x="Gender")
AX.bar_label(AX.containers[0])
plt.show()

# %% [markdown]
# ### From the above chart we have analysed that:the number of females in the data more than the the number of males

# %% [markdown]
# # In this way we can count for different columns

# %%
data['ParentEduc'].value_counts()
# Out:
# ParentEduc
# some college          6633
# high school           5687
# associate's degree    5550
# some high school      5517
# bachelor's degree     3386
# master's degree       2023
# Name: count, dtype: int64

# %%
data['EthnicGroup'].value_counts()
# Out:
# EthnicGroup
# group C    9212
# group D    7503
# group B    5826
# group E    4041
# group A    2219
# Name: count, dtype: int64

# %% [markdown]
# #  to find total number of marks of each student:-

# %%
data['total']=data['MathScore']+data['ReadingScore']+data['WritingScore']
data['total']
# Out:
# 0        216
# 1        247
# 2        271
# 3        143
# 4        229
#         ...
# 30636    185
# 30637    162
# 30638    198
# 30639    265
# 30640    182
# Name: total, Length: 30641, dtype: int64

# %% [markdown]
# # Avarage mark of each student:-

# %%
data['average']=data['total']/3
data['average']
# Out:
# 0        72.000000
# 1        82.333333
# 2        90.333333
# 3        47.666667
# 4        76.333333
#            ...
# 30636    61.666667
# 30637    54.000000
# 30638    66.000000
# 30639    88.333333
# 30640    60.666667
# Name: average, Length: 30641, dtype: float64

# %% [markdown]
# # Check student's marks are dependent on their parents education or not?

# %%
gb=data.groupby("ParentEduc").agg({"MathScore":"mean","ReadingScore":"mean","WritingScore":"mean"})
gb
# Out:
#                     MathScore  ReadingScore  WritingScore
# ParentEduc
# associate's degree  68.365586     71.124324     70.299099
# bachelor's degree   70.466627     73.062020     73.331069
# high school         64.435731     67.213997     65.421136
# master's degree     72.336134     75.832921     76.356896
# some college        66.390472     69.179708     68.501432
# some high school    62.584013     65.510785     63.632409

# %%
plt.figure(figsize=(5,5))
sns.heatmap(gb,annot=True)
plt.title("relation parent education and student score")
plt.show()

# %% [markdown]
# ### from above we can say that student's marks are effected with their parents education.

# %% [markdown]
# #  In this way we can check marks are effected with anything or not?

# %%
gb1=data.groupby("ParentMaritalStatus").agg({"MathScore":"mean","ReadingScore":"mean","WritingScore":"mean"})
gb1
# Out:
#                      MathScore  ReadingScore  WritingScore
# ParentMaritalStatus
# divorced             66.691197     69.655011     68.799146
# married              66.657326     69.389575     68.420981
# single               66.165704     69.157250     68.174440
# widowed              67.368866     69.651438     68.563452

# %%
plt.figure(figsize=(4,4))
sns.heatmap(gb1,annot=True)
plt.title("relation between parentmaritalstatus and student score")
plt.show()

# %% [markdown]
# ### from above we can say that student's marks are not effected with their Parents Marital Status.

# %%
gb3=data.groupby("WklyStudyHours").agg({"MathScore":"mean","ReadingScore":"mean","WritingScore":"mean"})
gb3
# Out:
#                 MathScore  ReadingScore  WritingScore
# WklyStudyHours
# 05-Oct          66.870491     69.660532     68.636280
# < 5             64.580359     68.176135     67.090192
# > 10            68.696655     70.365436     69.777778

# %%
plt.figure(figsize=(4,4))
sns.heatmap(gb3,annot=True)
plt.title("relation between weeklystudyhours and student score")
plt.show()

# %% [markdown]
# ### from above we can say that student's marks are  effected with their Weekly Study Hours.

# %%
gb5=data.groupby("PracticeSport").agg({"MathScore":"mean","ReadingScore":"mean","WritingScore":"mean"})
print(gb5)
plt.figure(figsize=(4,4))
sns.heatmap(gb5,annot=True)
plt.title("relation between practice sport and student score")
plt.show()
# Out:
#                MathScore  ReadingScore  WritingScore
# PracticeSport
# never          64.171079     68.337662     66.522727
# regularly      67.839155     69.943019     69.604003
# sometimes      66.274831     69.241307     68.072438

# %% [markdown]
# # from above we can say that student's marks are  effected with their sports.

# %%
gb6=data.groupby("Gender").agg({"MathScore":"mean","ReadingScore":"mean","WritingScore":"mean"})
print(gb6)
plt.figure(figsize=(4,4))
sns.heatmap(gb6,annot=True)
plt.title("relation between Gender and student score")
plt.show()
# Out:
#         MathScore  ReadingScore  WritingScore
# Gender
# female  64.080654     72.853216     72.856457
# male    69.069856     65.854571     63.920418

# %% [markdown]
# ### from above we can say that student's marks are  effected with their gender also.

# %%
gb7=data.groupby("LunchType").agg({"MathScore":"mean","ReadingScore":"mean","WritingScore":"mean"})
print(gb7)

plt.figure(figsize=(4,4))
sns.heatmap(gb7,annot=True)
plt.title("relation between lunchtype and student score")
plt.show()
# Out:
#               MathScore  ReadingScore  WritingScore
# LunchType
# free/reduced  58.862332     64.189735     62.650522
# standard      70.709370     72.175634     71.529716

# %% [markdown]
# ### from above we can say that student's marks are  effected with their lunch type.
